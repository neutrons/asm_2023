# %%
import glob
import os
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <cell line: 7>()
#       4 from PIL import Image
#       5 import matplotlib.pyplot as plt
# ----> 7 import ipywe
#
# ModuleNotFoundError: No module named 'ipywe'

# %% [markdown]
# ## Input data folder

# %%
data_folder = "./data/example1"

# %% [markdown]
# ### List files to load

# %%
list_files = glob.glob(os.path.join(data_folder, "*.tiff"))
print(f"list_files= {list_files}")
# Out:
# list_files= ['./data/example1/20191030_phytosaur_teeth_0070_131_070_0917.tiff', './data/example1/20191030_phytosaur_teeth_0070_000_000_0660.tiff', './data/example1/20191031_phytosaur_teeth_0070_340_170_1327.tiff', './data/example1/20191030_phytosaur_teeth_0070_005_610_0671.tiff', './data/example1/20191031_phytosaur_teeth_0070_315_180_1278.tiff', './data/example1/20191030_phytosaur_teeth_0070_066_300_0790.tiff', './data/example1/20191031_phytosaur_teeth_0070_189_720_1032.tiff', './data/example1/20191031_phytosaur_teeth_0070_357_000_1360.tiff', './data/example1/20191031_phytosaur_teeth_0070_330_990_1309.tiff', './data/example1/20191031_phytosaur_teeth_0070_328_950_1305.tiff']

# %% [markdown]
# ## Load data

# %%
images = []
for _file in list_files:
    _image = np.array(Image.open(_file))
    images.append(_image)

# %% [markdown]
# ### Visualize data

# %%
plt.figure(0)
plt.imshow(images[7])
plt.colorbar()

# %% [markdown]
# __exercise__: Let's now visualize image index 5, 7, and 10

# %% [markdown]
# ## Crop data

# %%
left = 500
right = 1500
top = 50
bottom = 1600

# %%
images_cropped = []
for _image in images:
    _image_cropped = _image[top: bottom, left: right]
    images_cropped.append(_image_cropped)

# %% [markdown]
# ### Visualize data cropped

# %%
plt.figure(1)
plt.imshow(images_cropped[0])
plt.colorbar()

# %% [markdown]
# ## Export data

# %%
output_folder = "./data/output/example1"

# %%
for _index, _image in enumerate(images_cropped):
    file_name = os.path.join(output_folder, f"cropped_image_{_index}.tiff")
    _image_to_export = Image.fromarray(_image)
    _image_to_export.save(file_name)
